# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

req = requests.get('https://api.github.com/events')
req.text
# Out:
# '[{"id":"11055804030","type":"PullRequestEvent","actor":{"id":39814207,"login":"pull[bot]","display_login":"pull","gravatar_id":"","url":"https://api.github.com/users/pull[bot]","avatar_url":"https://avatars.githubusercontent.com/u/39814207?"},"repo":{"id":181272238,"name":"onkelbeh/gentoo-dev","url":"https://api.github.com/repos/onkelbeh/gentoo-dev"},"payload":{"action":"closed","number":617,"pull_request":{"url":"https://api.github.com/repos/onkelbeh/gentoo-dev/pulls/617","id":351461155,"node_id":"MDExOlB1bGxSZXF1ZXN0MzUxNDYxMTU1","html_url":"https://github.com/onkelbeh/gentoo-dev/pull/617","diff_url":"https://github.com/onkelbeh/gentoo-dev/pull/617.diff","patch_url":"https://github.com/onkelbeh/gentoo-dev/pull/617.patch","issue_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/issues/617","number":617,"state":"closed","locked":false,"title":"[pull] master from gentoo:master","user":{"login":"pull[bot]","id":39814207,"node_id":"MDM6Qm90Mzk4MTQyMDc=","avatar_url":"https://avatars0.githubusercontent.com/in/12910?v=4","gravatar_id":"","url":"https://api.github.com/users/pull%5Bbot%5D","html_url":"https://github.com/apps/pull","followers_url":"https://api.github.com/users/pull%5Bbot%5D/followers","following_url":"https://api.github.com/users/pull%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/pull%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/pull%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/pull%5Bbot%5D/repos","events_url":"https://api.github.com/users/pull%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/pull%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"See [Commits](/onkelbeh/gentoo-dev/pull/617/commits) and [Changes](/onkelbeh/gentoo-dev/pull/617/files) for more details.\\n\\n-----\\nCreated by [<img src=\\"https://prod.download/pull-18h-svg\\" valign=\\"bottom\\"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)","created_at":"2019-12-10T15:49:29Z","updated_at":"2019-12-10T15:49:37Z","closed_at":"2019-12-10T15:49:36Z","merged_at":"2019-12-10T15:49:36Z","merge_commit_sha":"07d90afb62d6f6e5857ee87018fbc24473a523fc","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[{"id":1672819787,"node_id":"MDU6TGFiZWwxNjcyODE5Nzg3","url":"https://api.github.com/repos/onkelbeh/gentoo-dev/labels/:arrow_heading_down:%20pull","name":":arrow_heading_down: pull","color":"ededed","default":false,"description":null}],"milestone":null,"commits_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/pulls/617/commits","review_comments_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/pulls/617/comments","review_comment_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/pulls/comments{/number}","comments_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/issues/617/comments","statuses_url":"https://api.github.com/repos/onkelbeh/gentoo-dev/statuses/07d90afb62d6f6e5857ee87018fbc24473a523fc","head":{"label":"gentoo:master","ref":"master","sha":"07d90afb62d6f6e5857ee87018fbc24473a523fc","user":{"login":"gentoo","id":52242,"node_id":"MDEyOk9yZ2FuaXphdGlvbjUyMjQy","avatar_url":"https://avatars3.githubusercontent.com/u/52242?v=4","gravatar_id":"","url":"https://api.github.com/users/gentoo","html_url":"https://github.com/gentoo","followers_url":"https://api.github.com/users/gentoo/followers","following_url":"https://api.github.com/users/gentoo/following{/other_user}","gists_url":"https://api.github.com/users/gentoo/gists{/gist_id}","starred_url":"https://api.github.com/users/gentoo/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gentoo/subscriptions","organizations_url":"https://api.github.com/users/gentoo/orgs","r ...

# %%
import json

req = requests.get('https://api.github.com/events')
json.loads(req.text)
# Out:
# [{'id': '11055808450',
#   'type': 'PushEvent',
#   'actor': {'id': 53324035,
#    'login': 'Flakster',
#    'display_login': 'Flakster',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Flakster',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53324035?'},
#   'repo': {'id': 226956952,
#    'name': 'Flakster/Apple-page-clone',
#    'url': 'https://api.github.com/repos/Flakster/Apple-page-clone'},
#   'payload': {'push_id': 4379193444,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/homepage',
#    'head': 'b3c81732118de5b10e34bd9ae890a7318bc77530',
#    'before': '3c7b8ddb3b022c35943259b118b941c231471e7d',
#    'commits': [{'sha': 'b3c81732118de5b10e34bd9ae890a7318bc77530',
#      'author': {'email': 'carlos.santamaria@gmail.com', 'name': 'flakster'},
#      'message': 'fixed position of the big picture',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Flakster/Apple-page-clone/commits/b3c81732118de5b10e34bd9ae890a7318bc77530'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808447',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 18262383,
#    'login': 'IngaSchl',
#    'display_login': 'IngaSchl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IngaSchl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18262383?'},
#   'repo': {'id': 1690480,
#    'name': 'qgis/QGIS',
#    'url': 'https://api.github.com/repos/qgis/QGIS'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/qgis/QGIS/issues/33318',
#     'repository_url': 'https://api.github.com/repos/qgis/QGIS',
#     'labels_url': 'https://api.github.com/repos/qgis/QGIS/issues/33318/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/qgis/QGIS/issues/33318/comments',
#     'events_url': 'https://api.github.com/repos/qgis/QGIS/issues/33318/events',
#     'html_url': 'https://github.com/qgis/QGIS/issues/33318',
#     'id': 535783855,
#     'node_id': 'MDU6SXNzdWU1MzU3ODM4NTU=',
#     'number': 33318,
#     'title': "Data source manager's inner window shrinks when opening it for a second time",
#     'user': {'login': 'IngaSchl',
#      'id': 18262383,
#      'node_id': 'MDQ6VXNlcjE4MjYyMzgz',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/18262383?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/IngaSchl',
#      'html_url': 'https://github.com/IngaSchl',
#      'followers_url': 'https://api.github.com/users/IngaSchl/followers',
#      'following_url': 'https://api.github.com/users/IngaSchl/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/IngaSchl/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/IngaSchl/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/IngaSchl/subscriptions',
#      'organizations_url': 'https://api.github.com/users/IngaSchl/orgs',
#      'repos_url': 'https://api.github.com/users/IngaSchl/repos',
#      'events_url': 'https://api.github.com/users/IngaSchl/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/IngaSchl/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1375312689,
#       'node_id': 'MDU6TGFiZWwxMzc1MzEyNjg5',
#       'url': 'https://api.github.com/repos/qgis/QGIS/labels/Bug',
#       'name': 'Bug',
#       'color': 'ee0701',
#       'default': False,
#       'description': "Either a bug report, or a bug fix. Let's hope for the latter!"},
#      {'id': 1375312063,
#       'node_id': 'MDU6TGFiZWwxMzc1MzEyMDYz',
#       'url': 'https://api.github.com/repos/qgis/QGIS/labels/GUI/UX',
#       'name': 'GUI/UX',
#       'color': '3a73af',
#       'default': False,
#       'description': 'Related to QGIS application GUI or User Experience'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2019-12-10T14:56:38Z',
#     'updated_at': '2019-12-10T15:50:04Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "When opening the data source manager for a second time (after closing it once), the inner window of the input screen shrinks relative to the data source manager's outer window.\r\nOnly when adjusting the size of the outer window, the inner one adapts and shows its full extent.\r\n\r\n![qgis](https://user-images.githubusercontent.com/18262383/70540521-b5904800-1b65-11ea-9c67-326478d45d53.PNG)"},
#    'comment': {'url': 'https://api.github.com/repos/qgis/QGIS/issues/comments/564096996',
#     'html_url': 'https://github.com/qgis/QGIS/issues/33318#issuecomment-564096996',
#     'issue_url': 'https://api.github.com/repos/qgis/QGIS/issues/33318',
#     'id': 564096996,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2NDA5Njk5Ng==',
#     'user': {'login': 'IngaSchl',
#      'id': 18262383,
#      'node_id': 'MDQ6VXNlcjE4MjYyMzgz',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/18262383?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/IngaSchl',
#      'html_url': 'https://github.com/IngaSchl',
#      'followers_url': 'https://api.github.com/users/IngaSchl/followers',
#      'following_url': 'https://api.github.com/users/IngaSchl/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/IngaSchl/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/IngaSchl/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/IngaSchl/subscriptions',
#      'organizations_url': 'https://api.github.com/users/IngaSchl/orgs',
#      'repos_url': 'https://api.github.com/users/IngaSchl/repos',
#      'events_url': 'https://api.github.com/users/IngaSchl/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/IngaSchl/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-10T15:50:04Z',
#     'updated_at': '2019-12-10T15:50:04Z',
#     'author_association': 'NONE',
#     'body': 'sorry for replicating... affected is version 3.10'}},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 483444,
#    'login': 'qgis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/qgis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/483444?'}},
#  {'id': '11055808427',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735785,
#    'name': 'adeo-gitlab/sync-github-gitlab-30',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-30'},
#   'payload': {'ref': '2019-12-10_15-49-56_290_scenario2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11055808438',
#   'type': 'PushEvent',
#   'actor': {'id': 2472141,
#    'login': 'rkondratowicz',
#    'display_login': 'rkondratowicz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rkondratowicz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2472141?'},
#   'repo': {'id': 145695191,
#    'name': 'hmcts/bulk-scan-orchestrator',
#    'url': 'https://api.github.com/repos/hmcts/bulk-scan-orchestrator'},
#   'payload': {'push_id': 4379193450,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/return-500-status-for-internal-errors',
#    'head': 'd88d94b17fae39259b15aa35191307250b1e7006',
#    'before': '55b7da80790014f1167eae66a4fd43e2086185c4',
#    'commits': [{'sha': 'd88d94b17fae39259b15aa35191307250b1e7006',
#      'author': {'email': 'rkondr@gmail.com', 'name': 'Rafal Kondratowicz'},
#      'message': 'Send message in body',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hmcts/bulk-scan-orchestrator/commits/d88d94b17fae39259b15aa35191307250b1e7006'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 22817111,
#    'login': 'hmcts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hmcts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22817111?'}},
#  {'id': '11055808424',
#   'type': 'PushEvent',
#   'actor': {'id': 53237101,
#    'login': 'christiansaavedra',
#    'display_login': 'christiansaavedra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/christiansaavedra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53237101?'},
#   'repo': {'id': 218083173,
#    'name': 'axontraining/tienda',
#    'url': 'https://api.github.com/repos/axontraining/tienda'},
#   'payload': {'push_id': 4379193438,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'bc452f44596530744f058e1fd8a1e302adf48c7d',
#    'before': '9714726971826d9033743fd70da19496a265d00a',
#    'commits': [{'sha': '72d860d223d5f0d13ab8e0d989e6b1b781a1872f',
#      'author': {'email': 'saavedra.christian.ok@gmail.com',
#       'name': 'christiansaavedra'},
#      'message': 'cambio fecha PNL',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/axontraining/tienda/commits/72d860d223d5f0d13ab8e0d989e6b1b781a1872f'},
#     {'sha': 'bc452f44596530744f058e1fd8a1e302adf48c7d',
#      'author': {'email': 'saavedra.christian.ok@gmail.com',
#       'name': 'christiansaavedra'},
#      'message': 'cambio fecha pnl',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/axontraining/tienda/commits/bc452f44596530744f058e1fd8a1e302adf48c7d'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808421',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 293363,
#    'login': 'ehelms',
#    'display_login': 'ehelms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehelms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/293363?'},
#   'repo': {'id': 4663237,
#    'name': 'theforeman/foreman-packaging',
#    'url': 'https://api.github.com/repos/theforeman/foreman-packaging'},
#   'payload': {'action': 'opened',
#    'number': 4471,
#    'pull_request': {'url': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471',
#     'id': 351461437,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUxNDYxNDM3',
#     'html_url': 'https://github.com/theforeman/foreman-packaging/pull/4471',
#     'diff_url': 'https://github.com/theforeman/foreman-packaging/pull/4471.diff',
#     'patch_url': 'https://github.com/theforeman/foreman-packaging/pull/4471.patch',
#     'issue_url': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/4471',
#     'number': 4471,
#     'state': 'open',
#     'locked': False,
#     'title': 'Release Foreman 1.24.0',
#     'user': {'login': 'ehelms',
#      'id': 293363,
#      'node_id': 'MDQ6VXNlcjI5MzM2Mw==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/293363?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ehelms',
#      'html_url': 'https://github.com/ehelms',
#      'followers_url': 'https://api.github.com/users/ehelms/followers',
#      'following_url': 'https://api.github.com/users/ehelms/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ehelms/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ehelms/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ehelms/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ehelms/orgs',
#      'repos_url': 'https://api.github.com/users/ehelms/repos',
#      'events_url': 'https://api.github.com/users/ehelms/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ehelms/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "<!--\r\nIf your package needs to be released within one or more release streams, and/or distributions, please open PRs to each of those branches respectively. The easiest way to do this is to make the initial commit for the mainline branch (e.g. rpm/develop or deb/develop) and then cherry pick the commit hash onto each subsequent branch.\r\n\r\nSupported Versions:\r\n\r\n * Nightly\r\n * 1.24\r\n * 1.23\r\n * 1.22\r\n\r\nRPM Example:\r\n\r\n    git checkout -b rpm/develop-foreman-tasks-1.0.1 rpm/develop\r\n\r\n    # Make changes to update package\r\n\r\n    git commit -a -m 'Release foreman-tasks-1.0.1'\r\n    COMMIT=`git rev-parse HEAD`\r\n\r\n    git checkout -b rpm/1.20-foreman-tasks-1.0.1-1.20 rpm/1.20\r\n    git cherry-pick -x $COMMIT\r\n\r\nDEB Example:\r\n\r\n    git checkout -b deb/develop-foreman-tasks-1.0.1 deb/develop\r\n\r\n    # Make changes to update package\r\n\r\n    git commit -a -m 'Release foreman-tasks-1.0.1'\r\n    COMMIT=`git rev-parse HEAD`\r\n\r\n    git checkout -b deb/1.20-foreman-tasks-1.0.1-1.20 deb/1.20\r\n    git cherry-pick -x $COMMIT\r\n\r\nSee Foreman's [plugin maintainer documentation](https://projects.theforeman.org/projects/foreman/wiki/How_to_Create_a_Plugin#Release-strategies) for more information.\r\n-->\r\n",
#     'created_at': '2019-12-10T15:50:04Z',
#     'updated_at': '2019-12-10T15:50:04Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471/commits',
#     'review_comments_url': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471/comments',
#     'review_comment_url': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/4471/comments',
#     'statuses_url': 'https://api.github.com/repos/theforeman/foreman-packaging/statuses/1bfaccb1d50abf42d5122cb9f70e2e92e69ce584',
#     'head': {'label': 'ehelms:deb/1.24-foreman-1.24.0',
#      'ref': 'deb/1.24-foreman-1.24.0',
#      'sha': '1bfaccb1d50abf42d5122cb9f70e2e92e69ce584',
#      'user': {'login': 'ehelms',
#       'id': 293363,
#       'node_id': 'MDQ6VXNlcjI5MzM2Mw==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/293363?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ehelms',
#       'html_url': 'https://github.com/ehelms',
#       'followers_url': 'https://api.github.com/users/ehelms/followers',
#       'following_url': 'https://api.github.com/users/ehelms/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ehelms/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ehelms/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ehelms/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ehelms/orgs',
#       'repos_url': 'https://api.github.com/users/ehelms/repos',
#       'events_url': 'https://api.github.com/users/ehelms/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ehelms/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 16296122,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjI5NjEyMg==',
#       'name': 'foreman-packaging',
#       'full_name': 'ehelms/foreman-packaging',
#       'private': False,
#       'owner': {'login': 'ehelms',
#        'id': 293363,
#        'node_id': 'MDQ6VXNlcjI5MzM2Mw==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/293363?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ehelms',
#        'html_url': 'https://github.com/ehelms',
#        'followers_url': 'https://api.github.com/users/ehelms/followers',
#        'following_url': 'https://api.github.com/users/ehelms/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ehelms/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ehelms/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ehelms/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ehelms/orgs',
#        'repos_url': 'https://api.github.com/users/ehelms/repos',
#        'events_url': 'https://api.github.com/users/ehelms/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ehelms/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ehelms/foreman-packaging',
#       'description': 'Packaging files (RPMs, debs) for Foreman and its dependencies',
#       'fork': True,
#       'url': 'https://api.github.com/repos/ehelms/foreman-packaging',
#       'forks_url': 'https://api.github.com/repos/ehelms/foreman-packaging/forks',
#       'keys_url': 'https://api.github.com/repos/ehelms/foreman-packaging/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ehelms/foreman-packaging/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ehelms/foreman-packaging/teams',
#       'hooks_url': 'https://api.github.com/repos/ehelms/foreman-packaging/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ehelms/foreman-packaging/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ehelms/foreman-packaging/events',
#       'assignees_url': 'https://api.github.com/repos/ehelms/foreman-packaging/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ehelms/foreman-packaging/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ehelms/foreman-packaging/tags',
#       'blobs_url': 'https://api.github.com/repos/ehelms/foreman-packaging/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ehelms/foreman-packaging/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ehelms/foreman-packaging/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ehelms/foreman-packaging/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ehelms/foreman-packaging/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ehelms/foreman-packaging/languages',
#       'stargazers_url': 'https://api.github.com/repos/ehelms/foreman-packaging/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ehelms/foreman-packaging/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ehelms/foreman-packaging/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ehelms/foreman-packaging/subscription',
#       'commits_url': 'https://api.github.com/repos/ehelms/foreman-packaging/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ehelms/foreman-packaging/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ehelms/foreman-packaging/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ehelms/foreman-packaging/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ehelms/foreman-packaging/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ehelms/foreman-packaging/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ehelms/foreman-packaging/merges',
#       'archive_url': 'https://api.github.com/repos/ehelms/foreman-packaging/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ehelms/foreman-packaging/downloads',
#       'issues_url': 'https://api.github.com/repos/ehelms/foreman-packaging/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ehelms/foreman-packaging/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ehelms/foreman-packaging/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ehelms/foreman-packaging/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ehelms/foreman-packaging/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ehelms/foreman-packaging/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ehelms/foreman-packaging/deployments',
#       'created_at': '2014-01-27T23:07:06Z',
#       'updated_at': '2015-05-11T15:35:28Z',
#       'pushed_at': '2019-12-10T15:49:37Z',
#       'git_url': 'git://github.com/ehelms/foreman-packaging.git',
#       'ssh_url': 'git@github.com:ehelms/foreman-packaging.git',
#       'clone_url': 'https://github.com/ehelms/foreman-packaging.git',
#       'svn_url': 'https://github.com/ehelms/foreman-packaging',
#       'homepage': '',
#       'size': 364235,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Shell',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'rpm/katello'}},
#     'base': {'label': 'theforeman:deb/1.24',
#      'ref': 'deb/1.24',
#      'sha': 'ad3a7854aa8c33dbed70424b756bfee0fdca2728',
#      'user': {'login': 'theforeman',
#       'id': 1439844,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0Mzk4NDQ=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1439844?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/theforeman',
#       'html_url': 'https://github.com/theforeman',
#       'followers_url': 'https://api.github.com/users/theforeman/followers',
#       'following_url': 'https://api.github.com/users/theforeman/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/theforeman/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/theforeman/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/theforeman/subscriptions',
#       'organizations_url': 'https://api.github.com/users/theforeman/orgs',
#       'repos_url': 'https://api.github.com/users/theforeman/repos',
#       'events_url': 'https://api.github.com/users/theforeman/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/theforeman/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 4663237,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NjYzMjM3',
#       'name': 'foreman-packaging',
#       'full_name': 'theforeman/foreman-packaging',
#       'private': False,
#       'owner': {'login': 'theforeman',
#        'id': 1439844,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0Mzk4NDQ=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/1439844?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/theforeman',
#        'html_url': 'https://github.com/theforeman',
#        'followers_url': 'https://api.github.com/users/theforeman/followers',
#        'following_url': 'https://api.github.com/users/theforeman/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/theforeman/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/theforeman/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/theforeman/subscriptions',
#        'organizations_url': 'https://api.github.com/users/theforeman/orgs',
#        'repos_url': 'https://api.github.com/users/theforeman/repos',
#        'events_url': 'https://api.github.com/users/theforeman/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/theforeman/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/theforeman/foreman-packaging',
#       'description': 'Packaging files (RPMs, debs) for Foreman and its dependencies',
#       'fork': False,
#       'url': 'https://api.github.com/repos/theforeman/foreman-packaging',
#       'forks_url': 'https://api.github.com/repos/theforeman/foreman-packaging/forks',
#       'keys_url': 'https://api.github.com/repos/theforeman/foreman-packaging/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/theforeman/foreman-packaging/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/theforeman/foreman-packaging/teams',
#       'hooks_url': 'https://api.github.com/repos/theforeman/foreman-packaging/hooks',
#       'issue_events_url': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/theforeman/foreman-packaging/events',
#       'assignees_url': 'https://api.github.com/repos/theforeman/foreman-packaging/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/theforeman/foreman-packaging/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/theforeman/foreman-packaging/tags',
#       'blobs_url': 'https://api.github.com/repos/theforeman/foreman-packaging/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/theforeman/foreman-packaging/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/theforeman/foreman-packaging/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/theforeman/foreman-packaging/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/theforeman/foreman-packaging/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/theforeman/foreman-packaging/languages',
#       'stargazers_url': 'https://api.github.com/repos/theforeman/foreman-packaging/stargazers',
#       'contributors_url': 'https://api.github.com/repos/theforeman/foreman-packaging/contributors',
#       'subscribers_url': 'https://api.github.com/repos/theforeman/foreman-packaging/subscribers',
#       'subscription_url': 'https://api.github.com/repos/theforeman/foreman-packaging/subscription',
#       'commits_url': 'https://api.github.com/repos/theforeman/foreman-packaging/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/theforeman/foreman-packaging/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/theforeman/foreman-packaging/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/theforeman/foreman-packaging/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/theforeman/foreman-packaging/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/theforeman/foreman-packaging/merges',
#       'archive_url': 'https://api.github.com/repos/theforeman/foreman-packaging/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/theforeman/foreman-packaging/downloads',
#       'issues_url': 'https://api.github.com/repos/theforeman/foreman-packaging/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/theforeman/foreman-packaging/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/theforeman/foreman-packaging/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/theforeman/foreman-packaging/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/theforeman/foreman-packaging/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/theforeman/foreman-packaging/deployments',
#       'created_at': '2012-06-14T13:01:07Z',
#       'updated_at': '2019-11-30T19:06:19Z',
#       'pushed_at': '2019-12-10T15:46:09Z',
#       'git_url': 'git://github.com/theforeman/foreman-packaging.git',
#       'ssh_url': 'git@github.com:theforeman/foreman-packaging.git',
#       'clone_url': 'https://github.com/theforeman/foreman-packaging.git',
#       'svn_url': 'https://github.com/theforeman/foreman-packaging',
#       'homepage': '',
#       'size': 310715,
#       'stargazers_count': 34,
#       'watchers_count': 34,
#       'language': None,
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 121,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 33,
#       'license': None,
#       'forks': 121,
#       'open_issues': 33,
#       'watchers': 34,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471'},
#      'html': {'href': 'https://github.com/theforeman/foreman-packaging/pull/4471'},
#      'issue': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/4471'},
#      'comments': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/issues/4471/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/pulls/4471/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/theforeman/foreman-packaging/statuses/1bfaccb1d50abf42d5122cb9f70e2e92e69ce584'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 72,
#     'deletions': 0,
#     'changed_files': 12}},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 1439844,
#    'login': 'theforeman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/theforeman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1439844?'}},
#  {'id': '11055808426',
#   'type': 'PushEvent',
#   'actor': {'id': 58551592,
#    'login': 'nures',
#    'display_login': 'nures',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nures',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58551592?'},
#   'repo': {'id': 227154782,
#    'name': 'nures/lab4',
#    'url': 'https://api.github.com/repos/nures/lab4'},
#   'payload': {'push_id': 4379193430,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7f5027a8c890679c5ea3b55edbf6c9584dc96b9f',
#    'before': '9f140848b38b6fdf636a419e89c9089f08d2cc23',
#    'commits': [{'sha': '7f5027a8c890679c5ea3b55edbf6c9584dc96b9f',
#      'author': {'email': '58551592+nures@users.noreply.github.com',
#       'name': 'nures'},
#      'message': 'Delete CompilerLD',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nures/lab4/commits/7f5027a8c890679c5ea3b55edbf6c9584dc96b9f'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808425',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 50836043,
#    'login': 'Codeatmos',
#    'display_login': 'Codeatmos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Codeatmos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50836043?'},
#   'repo': {'id': 120966336,
#    'name': 'yogstation13/Yogstation',
#    'url': 'https://api.github.com/repos/yogstation13/Yogstation'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/7298',
#     'repository_url': 'https://api.github.com/repos/yogstation13/Yogstation',
#     'labels_url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/7298/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/7298/comments',
#     'events_url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/7298/events',
#     'html_url': 'https://github.com/yogstation13/Yogstation/pull/7298',
#     'id': 535522830,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUxMjIxODk1',
#     'number': 7298,
#     'title': 'Da great American foods update. Many many hamberders, resprites and more!',
#     'user': {'login': 'Hopekz',
#      'id': 24533979,
#      'node_id': 'MDQ6VXNlcjI0NTMzOTc5',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/24533979?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Hopekz',
#      'html_url': 'https://github.com/Hopekz',
#      'followers_url': 'https://api.github.com/users/Hopekz/followers',
#      'following_url': 'https://api.github.com/users/Hopekz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Hopekz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Hopekz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Hopekz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Hopekz/orgs',
#      'repos_url': 'https://api.github.com/users/Hopekz/repos',
#      'events_url': 'https://api.github.com/users/Hopekz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Hopekz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2019-12-10T06:26:55Z',
#     'updated_at': '2019-12-10T15:50:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/yogstation13/Yogstation/pulls/7298',
#      'html_url': 'https://github.com/yogstation13/Yogstation/pull/7298',
#      'diff_url': 'https://github.com/yogstation13/Yogstation/pull/7298.diff',
#      'patch_url': 'https://github.com/yogstation13/Yogstation/pull/7298.patch'},
#     'body': 'ports tgstation/tgstation#48050\r\n\r\n**Wow, this one was a doozy. FUCK**\r\nfixed for our codebase.\r\nLots of content tested it as much as I could.\r\n\r\nOriginal Description:\r\n"\r\nThis PR adds the following new dishes:\r\n\r\nCheese burger\r\nSoylent burger\r\nMcRib\r\nMcGuffin\r\nChicken Sandwich\r\nFiesta Skewer\r\nBoritos corn chips\r\nChicken meat & cutlet\r\n\r\nThis PR also resprites many old burgers such as:\r\nHamburger\r\nFilet-o-Fish sandwich\r\nBacon burger\r\nBig bite burger\r\nSuper big bite burger\r\nFive alarm burger\r\nGhost burger\r\n\r\nSome burger recipes have been changed to better match the sprite and ghostburger has been reworked to be much spookier.\r\n![69885376-15246300-12dd-11ea-97ae-ce7095c277c7 1](https://user-images.githubusercontent.com/24533979/70501429-ab2d6a00-1ae3-11ea-987b-e13d6ab86e92.png)\r\n![69885560-038f8b00-12de-11ea-922f-1b6e89610e36 1](https://user-images.githubusercontent.com/24533979/70501442-b08ab480-1ae3-11ea-9318-aa73400c54e3.gif)\r\n![69885558-fe324080-12dd-11ea-918c-5bf9d2bc6cf5 1](https://user-images.githubusercontent.com/24533979/70501450-b4b6d200-1ae3-11ea-82a9-1dfe95a26ca0.png)\r\n\r\n\r\nburg_comparasion\r\nfiesta64\r\nghostburgerglow64\r\n\r\nWhy It\'s Good For The Game\r\nMany of the current burger sprites are pretty sad and fast food is a fun chef gimmick.\r\n"\r\n\r\n#### Changelog\r\n\r\n:cl:  \r\nadd: Several new burgers.\r\nadd: Fiesta skewer, corn chips & chicken meat.\r\ndel: some old burger sprites have been replaced.\r\ntweak: The ghost burger is much spookier.\r\nbalance: some burger recipes have been tweaked.\r\n/:cl:\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/comments/564096995',
#     'html_url': 'https://github.com/yogstation13/Yogstation/pull/7298#issuecomment-564096995',
#     'issue_url': 'https://api.github.com/repos/yogstation13/Yogstation/issues/7298',
#     'id': 564096995,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2NDA5Njk5NQ==',
#     'user': {'login': 'Codeatmos',
#      'id': 50836043,
#      'node_id': 'MDQ6VXNlcjUwODM2MDQz',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/50836043?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Codeatmos',
#      'html_url': 'https://github.com/Codeatmos',
#      'followers_url': 'https://api.github.com/users/Codeatmos/followers',
#      'following_url': 'https://api.github.com/users/Codeatmos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Codeatmos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Codeatmos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Codeatmos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Codeatmos/orgs',
#      'repos_url': 'https://api.github.com/users/Codeatmos/repos',
#      'events_url': 'https://api.github.com/users/Codeatmos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Codeatmos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-10T15:50:04Z',
#     'updated_at': '2019-12-10T15:50:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "I don't think we have ported the BBQ yet, we should I need to lube up mah arteries with some alabamaian steak sauce "}},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 16735403,
#    'login': 'yogstation13',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/yogstation13',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16735403?'}},
#  {'id': '11055808423',
#   'type': 'CreateEvent',
#   'actor': {'id': 31429439,
#    'login': 'Dibyajyoti123',
#    'display_login': 'Dibyajyoti123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dibyajyoti123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31429439?'},
#   'repo': {'id': 227158614,
#    'name': 'Dibyajyoti123/angular-eg1cmo',
#    'url': 'https://api.github.com/repos/Dibyajyoti123/angular-eg1cmo'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Created with StackBlitz ⚡️',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808404',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10100000,
#    'login': 'Anuken',
#    'display_login': 'Anuken',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anuken',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10100000?'},
#   'repo': {'id': 89822531,
#    'name': 'Anuken/Mindustry',
#    'url': 'https://api.github.com/repos/Anuken/Mindustry'},
#   'payload': {'ref': 'rhino-js-suffering',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808417',
#   'type': 'WatchEvent',
#   'actor': {'id': 19796163,
#    'login': 'ismailbennani',
#    'display_login': 'ismailbennani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ismailbennani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19796163?'},
#   'repo': {'id': 220264157,
#    'name': 'fadbadml-dev/FADBADml',
#    'url': 'https://api.github.com/repos/fadbadml-dev/FADBADml'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 57494807,
#    'login': 'fadbadml-dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/fadbadml-dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57494807?'}},
#  {'id': '11055808402',
#   'type': 'CreateEvent',
#   'actor': {'id': 49060557,
#    'login': 'igdmdimitrov',
#    'display_login': 'igdmdimitrov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/igdmdimitrov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49060557?'},
#   'repo': {'id': 51516387,
#    'name': 'IgniteUI/igniteui-angular',
#    'url': 'https://api.github.com/repos/IgniteUI/igniteui-angular'},
#   'payload': {'ref': 'dmdimitrov/issue6224-8.2.x',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Ignite UI for Angular is a dependency-free Angular toolkit for building modern web apps.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 5366066,
#    'login': 'IgniteUI',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/IgniteUI',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5366066?'}},
#  {'id': '11055808418',
#   'type': 'CreateEvent',
#   'actor': {'id': 56686701,
#    'login': 'Mystwalker131',
#    'display_login': 'Mystwalker131',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mystwalker131',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56686701?'},
#   'repo': {'id': 227158651,
#    'name': 'Mystwalker131/Mystwalker131.github.io',
#    'url': 'https://api.github.com/repos/Mystwalker131/Mystwalker131.github.io'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808385',
#   'type': 'PushEvent',
#   'actor': {'id': 2768983,
#    'login': 'gossie',
#    'display_login': 'gossie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gossie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2768983?'},
#   'repo': {'id': 226908787,
#    'name': 'gossie/array-pipe',
#    'url': 'https://api.github.com/repos/gossie/array-pipe'},
#   'payload': {'push_id': 4379193409,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7cdc0395907e42f7d4118b949bb44dea0ad56c10',
#    'before': 'c7999590a18e78cc04f0f4912afe9ef1b5a6dd50',
#    'commits': [{'sha': '7cdc0395907e42f7d4118b949bb44dea0ad56c10',
#      'author': {'email': 'andre.schreck@gmail.com', 'name': 'André Schreck'},
#      'message': 'prepare prerelease',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gossie/array-pipe/commits/7cdc0395907e42f7d4118b949bb44dea0ad56c10'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808383',
#   'type': 'PushEvent',
#   'actor': {'id': 19969910,
#    'login': 'TimonPost',
#    'display_login': 'TimonPost',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TimonPost',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19969910?'},
#   'repo': {'id': 116140523,
#    'name': 'crossterm-rs/crossterm',
#    'url': 'https://api.github.com/repos/crossterm-rs/crossterm'},
#   'payload': {'push_id': 4379193419,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/timon/poll_wake_fix',
#    'head': 'e8200b9d430f36c2bf25a6de2e9dc93235bee934',
#    'before': '6b67873d399b00f7b8b7d8a6fcaebd43c2503d26',
#    'commits': [{'sha': 'e8200b9d430f36c2bf25a6de2e9dc93235bee934',
#      'author': {'email': 'timonpost@hotmail.com', 'name': 'TimonPost'},
#      'message': 'Fixed unix build',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/crossterm-rs/crossterm/commits/e8200b9d430f36c2bf25a6de2e9dc93235bee934'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 55745280,
#    'login': 'crossterm-rs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/crossterm-rs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55745280?'}},
#  {'id': '11055808407',
#   'type': 'PushEvent',
#   'actor': {'id': 32189139,
#    'login': 'caobo171',
#    'display_login': 'caobo171',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/caobo171',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32189139?'},
#   'repo': {'id': 213619230,
#    'name': 'caobo171/wele-app',
#    'url': 'https://api.github.com/repos/caobo171/wele-app'},
#   'payload': {'push_id': 4379193431,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/refactor',
#    'head': 'da0908733d84bf4fd0d800f82a3bcb13d3d35f03',
#    'before': 'e01c32e6bdb35cec2e54584407101d11afb32cc4',
#    'commits': [{'sha': 'da0908733d84bf4fd0d800f82a3bcb13d3d35f03',
#      'author': {'email': 'caobo1712000@gmail.com', 'name': 'caobo171'},
#      'message': 'done local file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/caobo171/wele-app/commits/da0908733d84bf4fd0d800f82a3bcb13d3d35f03'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808399',
#   'type': 'PushEvent',
#   'actor': {'id': 37111320,
#    'login': 'SolalThoniel',
#    'display_login': 'SolalThoniel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SolalThoniel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37111320?'},
#   'repo': {'id': 225809768,
#    'name': 'SolalThoniel/Web_Semantique_Project',
#    'url': 'https://api.github.com/repos/SolalThoniel/Web_Semantique_Project'},
#   'payload': {'push_id': 4379193422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/page_2',
#    'head': '3d6ea43d5067387b5692102f6cdaa76fb4cf9e99',
#    'before': '498b4475315394e73916cb3c78425735a813bcfb',
#    'commits': [{'sha': '3d6ea43d5067387b5692102f6cdaa76fb4cf9e99',
#      'author': {'email': 'solalthoniel@gmail.com', 'name': 'Solal Thoniel'},
#      'message': 'Passage des mots cles de la page 1 a la page 2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SolalThoniel/Web_Semantique_Project/commits/3d6ea43d5067387b5692102f6cdaa76fb4cf9e99'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808390',
#   'type': 'PushEvent',
#   'actor': {'id': 45532663,
#    'login': 'ma-jones',
#    'display_login': 'ma-jones',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ma-jones',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45532663?'},
#   'repo': {'id': 227153007,
#    'name': 'ma-jones/cb',
#    'url': 'https://api.github.com/repos/ma-jones/cb'},
#   'payload': {'push_id': 4379193403,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8cb7929485e419d6962fb36a0c7352dff9e4f432',
#    'before': '2c39a46262b65eb2b99212fa23427c7a9287e12d',
#    'commits': [{'sha': '8cb7929485e419d6962fb36a0c7352dff9e4f432',
#      'author': {'email': '45532663+ma-jones@users.noreply.github.com',
#       'name': 'ma-jones'},
#      'message': 'Create CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ma-jones/cb/commits/8cb7929485e419d6962fb36a0c7352dff9e4f432'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808395',
#   'type': 'PushEvent',
#   'actor': {'id': 43889523,
#    'login': 'annaarendt',
#    'display_login': 'annaarendt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/annaarendt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43889523?'},
#   'repo': {'id': 225231906,
#    'name': 'annaarendt/nQueens',
#    'url': 'https://api.github.com/repos/annaarendt/nQueens'},
#   'payload': {'push_id': 4379193416,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cf82cd12629e8db5c14a338529bf58243bafb9a0',
#    'before': '0e64bb5606ee06ac97ca67f2bbdb4c552618878e',
#    'commits': [{'sha': 'cf82cd12629e8db5c14a338529bf58243bafb9a0',
#      'author': {'email': 'anna.arendt@campus.lmu.de', 'name': 'Anna'},
#      'message': 'fixed orderbased',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/annaarendt/nQueens/commits/cf82cd12629e8db5c14a338529bf58243bafb9a0'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808388',
#   'type': 'PushEvent',
#   'actor': {'id': 22912273,
#    'login': 'FlorianVeaux',
#    'display_login': 'FlorianVeaux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FlorianVeaux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22912273?'},
#   'repo': {'id': 47203045,
#    'name': 'DataDog/integrations-core',
#    'url': 'https://api.github.com/repos/DataDog/integrations-core'},
#   'payload': {'push_id': 4379193404,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/flo/vsphere_v2',
#    'head': 'c2835620295e8138462a19f9ac4396795246d3c4',
#    'before': '41beaf642602bf876e0d8ee6e75b3150f2b73c4c',
#    'commits': [{'sha': 'ef9a2a1d88503c48f039f7b387305ada803591c4',
#      'author': {'email': 'florian.veaux@datadoghq.com',
#       'name': 'florian.veaux'},
#      'message': 'tmp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DataDog/integrations-core/commits/ef9a2a1d88503c48f039f7b387305ada803591c4'},
#     {'sha': 'c2835620295e8138462a19f9ac4396795246d3c4',
#      'author': {'email': 'florian.veaux@datadoghq.com',
#       'name': 'florian.veaux'},
#      'message': 'more',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DataDog/integrations-core/commits/c2835620295e8138462a19f9ac4396795246d3c4'}]},
#   'public': True,
# ...
#       'html_url': 'https://github.com/codeamo',
#       'followers_url': 'https://api.github.com/users/codeamo/followers',
#       'following_url': 'https://api.github.com/users/codeamo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/codeamo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/codeamo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/codeamo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/codeamo/orgs',
#       'repos_url': 'https://api.github.com/users/codeamo/repos',
#       'events_url': 'https://api.github.com/users/codeamo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/codeamo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 223626386,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjM2MjYzODY=',
#       'name': 'TripWorks',
#       'full_name': 'codeamo/TripWorks',
#       'private': False,
#       'owner': {'login': 'codeamo',
#        'id': 46251634,
#        'node_id': 'MDQ6VXNlcjQ2MjUxNjM0',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/46251634?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/codeamo',
#        'html_url': 'https://github.com/codeamo',
#        'followers_url': 'https://api.github.com/users/codeamo/followers',
#        'following_url': 'https://api.github.com/users/codeamo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/codeamo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/codeamo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/codeamo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/codeamo/orgs',
#        'repos_url': 'https://api.github.com/users/codeamo/repos',
#        'events_url': 'https://api.github.com/users/codeamo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/codeamo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/codeamo/TripWorks',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/codeamo/TripWorks',
#       'forks_url': 'https://api.github.com/repos/codeamo/TripWorks/forks',
#       'keys_url': 'https://api.github.com/repos/codeamo/TripWorks/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/codeamo/TripWorks/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/codeamo/TripWorks/teams',
#       'hooks_url': 'https://api.github.com/repos/codeamo/TripWorks/hooks',
#       'issue_events_url': 'https://api.github.com/repos/codeamo/TripWorks/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/codeamo/TripWorks/events',
#       'assignees_url': 'https://api.github.com/repos/codeamo/TripWorks/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/codeamo/TripWorks/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/codeamo/TripWorks/tags',
#       'blobs_url': 'https://api.github.com/repos/codeamo/TripWorks/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/codeamo/TripWorks/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/codeamo/TripWorks/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/codeamo/TripWorks/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/codeamo/TripWorks/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/codeamo/TripWorks/languages',
#       'stargazers_url': 'https://api.github.com/repos/codeamo/TripWorks/stargazers',
#       'contributors_url': 'https://api.github.com/repos/codeamo/TripWorks/contributors',
#       'subscribers_url': 'https://api.github.com/repos/codeamo/TripWorks/subscribers',
#       'subscription_url': 'https://api.github.com/repos/codeamo/TripWorks/subscription',
#       'commits_url': 'https://api.github.com/repos/codeamo/TripWorks/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/codeamo/TripWorks/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/codeamo/TripWorks/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/codeamo/TripWorks/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/codeamo/TripWorks/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/codeamo/TripWorks/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/codeamo/TripWorks/merges',
#       'archive_url': 'https://api.github.com/repos/codeamo/TripWorks/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/codeamo/TripWorks/downloads',
#       'issues_url': 'https://api.github.com/repos/codeamo/TripWorks/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/codeamo/TripWorks/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/codeamo/TripWorks/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/codeamo/TripWorks/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/codeamo/TripWorks/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/codeamo/TripWorks/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/codeamo/TripWorks/deployments',
#       'created_at': '2019-11-23T17:20:34Z',
#       'updated_at': '2019-12-10T15:39:19Z',
#       'pushed_at': '2019-12-10T15:50:04Z',
#       'git_url': 'git://github.com/codeamo/TripWorks.git',
#       'ssh_url': 'git@github.com:codeamo/TripWorks.git',
#       'clone_url': 'https://github.com/codeamo/TripWorks.git',
#       'svn_url': 'https://github.com/codeamo/TripWorks',
#       'homepage': None,
#       'size': 10565,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/codeamo/TripWorks/pulls/44'},
#      'html': {'href': 'https://github.com/codeamo/TripWorks/pull/44'},
#      'issue': {'href': 'https://api.github.com/repos/codeamo/TripWorks/issues/44'},
#      'comments': {'href': 'https://api.github.com/repos/codeamo/TripWorks/issues/44/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/codeamo/TripWorks/pulls/44/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/codeamo/TripWorks/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/codeamo/TripWorks/pulls/44/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/codeamo/TripWorks/statuses/f966572ebc5c99bad5bbc9db961c3630a2f4a176'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'bmch',
#      'id': 10965447,
#      'node_id': 'MDQ6VXNlcjEwOTY1NDQ3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/10965447?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bmch',
#      'html_url': 'https://github.com/bmch',
#      'followers_url': 'https://api.github.com/users/bmch/followers',
#      'following_url': 'https://api.github.com/users/bmch/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bmch/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bmch/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bmch/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bmch/orgs',
#      'repos_url': 'https://api.github.com/users/bmch/repos',
#      'events_url': 'https://api.github.com/users/bmch/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bmch/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808349',
#   'type': 'PushEvent',
#   'actor': {'id': 4924168,
#    'login': 'GunnarHolwerda',
#    'display_login': 'GunnarHolwerda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GunnarHolwerda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4924168?'},
#   'repo': {'id': 184446725,
#    'name': 'OpenSesame/Actions',
#    'url': 'https://api.github.com/repos/OpenSesame/Actions'},
#   'payload': {'push_id': 4379193402,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/test',
#    'head': '4adf6c563d1de3d537b92a9285204eccfbee977a',
#    'before': 'e01977d54f531c5c8cebd496ea667a9f9725a7c3',
#    'commits': [{'sha': '4adf6c563d1de3d537b92a9285204eccfbee977a',
#      'author': {'email': 'gunnar.holwerda@opensesame.com',
#       'name': 'Gunnar Holwerda'},
#      'message': 'Run full path of bash script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OpenSesame/Actions/commits/4adf6c563d1de3d537b92a9285204eccfbee977a'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 264714,
#    'login': 'OpenSesame',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OpenSesame',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/264714?'}},
#  {'id': '11055808347',
#   'type': 'CreateEvent',
#   'actor': {'id': 51339532,
#    'login': 'ankoyeeri',
#    'display_login': 'ankoyeeri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ankoyeeri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51339532?'},
#   'repo': {'id': 224992912,
#    'name': 'ankoyeeri/StudentPerformanceTracking',
#    'url': 'https://api.github.com/repos/ankoyeeri/StudentPerformanceTracking'},
#   'payload': {'ref': 'ST25',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z'},
#  {'id': '11055808323',
#   'type': 'PushEvent',
#   'actor': {'id': 16366709,
#    'login': 'IdrisKalp',
#    'display_login': 'IdrisKalp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IdrisKalp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16366709?'},
#   'repo': {'id': 37426721,
#    'name': 'pisilinux/main',
#    'url': 'https://api.github.com/repos/pisilinux/main'},
#   'payload': {'push_id': 4379193384,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'e94946e29931dee6f53fa9f0192fc69d8e71f84b',
#    'before': '2475add8a73e8ed3ce915c6958b36894f8c9bd5e',
#    'commits': [{'sha': '0bd47f5928f6bb43646adee7a9898dc467ac6ed6',
#      'author': {'email': 'idriskalp@gmail.com', 'name': 'IdrisKalp'},
#      'message': 'mpdecimal move to core',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pisilinux/main/commits/0bd47f5928f6bb43646adee7a9898dc467ac6ed6'},
#     {'sha': 'e94946e29931dee6f53fa9f0192fc69d8e71f84b',
#      'author': {'email': 'idriskalp@gmail.com', 'name': 'Idris Kalp'},
#      'message': 'Merge pull request #7308 from IdrisKalp/master\n\nmpdecimal move to core',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pisilinux/main/commits/e94946e29931dee6f53fa9f0192fc69d8e71f84b'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:03Z',
#   'org': {'id': 3696896,
#    'login': 'pisilinux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pisilinux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3696896?'}},
#  {'id': '11055808331',
#   'type': 'PushEvent',
#   'actor': {'id': 814283,
#    'login': 'tmcconechy',
#    'display_login': 'tmcconechy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tmcconechy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/814283?'},
#   'repo': {'id': 129261824,
#    'name': 'infor-design/enterprise',
#    'url': 'https://api.github.com/repos/infor-design/enterprise'},
#   'payload': {'push_id': 4379193390,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/2825-sticky-datagrid',
#    'head': 'c34eaad20d7cdf2ad0d1ae41b969cd768501ae31',
#    'before': '5d03d01e2bcd03810e730804198b73359d656b1a',
#    'commits': [{'sha': 'c34eaad20d7cdf2ad0d1ae41b969cd768501ae31',
#      'author': {'email': 'tim.mcconechy@infor.com', 'name': 'tmcconechy'},
#      'message': 'Add a new visual regression test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/infor-design/enterprise/commits/c34eaad20d7cdf2ad0d1ae41b969cd768501ae31'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 34451360,
#    'login': 'infor-design',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/infor-design',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34451360?'}},
#  {'id': '11055808336',
#   'type': 'PushEvent',
#   'actor': {'id': 6065744,
#    'login': 'alexandrebodin',
#    'display_login': 'alexandrebodin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexandrebodin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6065744?'},
#   'repo': {'id': 43441403,
#    'name': 'strapi/strapi',
#    'url': 'https://api.github.com/repos/strapi/strapi'},
#   'payload': {'push_id': 4379193392,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'e7444474f0e709d95348cc4244b94da921114793',
#    'before': '93ea08cc963715f6729fe98b949777264afc4966',
#    'commits': [{'sha': '03193acf4fdb9ae3f1d3b0f72b466aacee6e377f',
#      'author': {'email': 'bodin.alex@gmail.com', 'name': 'Alexandre Bodin'},
#      'message': 'Remove populate role on non existing relation breaking mongoose',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/strapi/strapi/commits/03193acf4fdb9ae3f1d3b0f72b466aacee6e377f'},
#     {'sha': 'f822a4d27953e50fba618eb2bdd7044d48371f23',
#      'author': {'email': 'alexandrebodin@users.noreply.github.com',
#       'name': 'Alexandre BODIN'},
#      'message': 'Merge pull request #4697 from strapi/fix/administrator-no-role-relation\n\nRemove populate role on non existing relation breaking mongoose',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/strapi/strapi/commits/f822a4d27953e50fba618eb2bdd7044d48371f23'},
#     {'sha': 'e7444474f0e709d95348cc4244b94da921114793',
#      'author': {'email': 'bodin.alex@gmail.com', 'name': 'Alexandre Bodin'},
#      'message': "Merge branch 'master' into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/strapi/strapi/commits/e7444474f0e709d95348cc4244b94da921114793'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:04Z',
#   'org': {'id': 19872173,
#    'login': 'strapi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/strapi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19872173?'}},
#  {'id': '11055808316',
#   'type': 'PushEvent',
#   'actor': {'id': 6359326,
#    'login': 'kbat',
#    'display_login': 'kbat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kbat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6359326?'},
#   'repo': {'id': 33251562,
#    'name': 'kbat/mc-tools',
#    'url': 'https://api.github.com/repos/kbat/mc-tools'},
#   'payload': {'push_id': 4379193377,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2c42193f29168b417706f5d1ca8a487055d43fc1',
#    'before': 'abba1b154dfe88da93d10e9d76c05cfa4971e568',
#    'commits': [{'sha': '2c42193f29168b417706f5d1ca8a487055d43fc1',
#      'author': {'email': 'konstantin.batkov@maxiv.lu.se',
#       'name': 'Konstantin Batkov'},
#      'message': '-type argument added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kbat/mc-tools/commits/2c42193f29168b417706f5d1ca8a487055d43fc1'}]},
#   'public': True,
#   'created_at': '2019-12-10T15:50:03Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

req = requests.get('https://cat-fact.herokuapp.com/facts')
req.text
# Out:
# '{"all":[{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e00a120aac31001185ed17","text":"A cat\'s brain is 90% similar to a human\'s — more similar than to a dog\'s.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"587288f6e6f85e64ae1c7ef7","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"5974fb4dfedacb0020b5b4cc","text":"Cats can survive falls from up to 65 feet or more.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","text":"Most cats don\'t like water because their coats do not insulate them well enough.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"5a4d76916ef087002174c28b","text":"A cat ...
